# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 582

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsarevo
# Processing Record 2 of Set 1 | muzaffarabad
# Processing Record 3 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 1 | waitangi
# Processing Record 5 of Set 1 | nelson bay
# Processing Record 6 of Set 1 | cockburn town
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | saudarkrokur
# Processing Record 9 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 10 of Set 1 | grytviken
# Processing Record 11 of Set 1 | hawaiian paradise park
# Processing Record 12 of Set 1 | invercargill
# Processing Record 13 of Set 1 | taoudenni
# Processing Record 14 of Set 1 | puerto carreno
# Processing Record 15 of Set 1 | hotan
# Processing Record 16 of Set 1 | kodiak
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | songjianghe
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | klyuchi
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | gopalpur
# Processing Record 24 of Set 1 | enewetak
# Processing Record 25 of Set 1 | papatowai
# Processing Record 26 of Set 1 | amga
# Processing Record 27 of Set 1 | wailua homesteads
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | uturoa
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | olonkinbyen
# Processing Record 32 of Set 1 | porto de moz
# Processing Record 33 of Set 1 | mooirivier
# Processing Record 34 of Set 1 | ciro marina
# Processing Record 35 of Set 1 | wainwright
# Processing Record 36 of Set 1 | shalya
# Processing Record 37 of Set 1 | zelenogorsk
# Processing Record 38 of Set 1 | margaret river
# Processing Record 39 of Set 1 | fort bragg
# Processing Record 40 of Set 1 | puerto natales
# Processing Record 41 of Set 1 | blackmans bay
# Processing Record 42 of Set 1 | edinburgh of the seven seas
# Processing Record 43 of Set 1 | aasiaat
# Processing Record 44 of Set 1 | alofi
# Processing Record 45 of Set 1 | motilla del palancar
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | dhidhdhoo
# Processing Record 48 of Set 1 | adamstown
# Processing Record 49 of Set 1 | sari
# Processing Record 50 of Set 1 | al jawf
# Processing Record 0 of Set 2 | saint simons island
# City not found. Skipping...
# Processing Record 1 of Set 2 | robertsport
# Processing Record 2 of Set 2 | pecangaan
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | santa cruz
# Processing Record 5 of Set 2 | hadibu
# Processing Record 6 of Set 2 | nuuk
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | atafu village
# Processing Record 9 of Set 2 | illela
# Processing Record 10 of Set 2 | montrose
# Processing Record 11 of Set 2 | whitehorse
# Processing Record 12 of Set 2 | reggane
# Processing Record 13 of Set 2 | alotau
# Processing Record 14 of Set 2 | vegreville
# Processing Record 15 of Set 2 | salalah
# Processing Record 16 of Set 2 | xinguara
# City not found. Skipping...
# Processing Record 17 of Set 2 | cruz
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | tazacorte
# Processing Record 20 of Set 2 | crane
# Processing Record 21 of Set 2 | rio grande
# Processing Record 22 of Set 2 | ruteng
# Processing Record 23 of Set 2 | mablethorpe
# City not found. Skipping...
# Processing Record 24 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 25 of Set 2 | st. john's
# Processing Record 26 of Set 2 | port lincoln
# Processing Record 27 of Set 2 | beihai
# Processing Record 28 of Set 2 | katsuura
# Processing Record 29 of Set 2 | kalispell
# Processing Record 30 of Set 2 | keflavik
# Processing Record 31 of Set 2 | tughyl
# Processing Record 32 of Set 2 | stanley
# Processing Record 33 of Set 2 | sinabang
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | hammerfest
# Processing Record 36 of Set 2 | farafangana
# Processing Record 37 of Set 2 | sanya
# Processing Record 38 of Set 2 | iqaluit
# Processing Record 39 of Set 2 | massawa
# Processing Record 40 of Set 2 | susuman
# Processing Record 41 of Set 2 | yoko
# Processing Record 42 of Set 2 | oleiros
# Processing Record 43 of Set 2 | port mathurin
# Processing Record 44 of Set 2 | kuta
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | al qitena
# Processing Record 47 of Set 2 | punta arenas
# Processing Record 48 of Set 2 | illizi
# Processing Record 49 of Set 2 | ust-nera
# Processing Record 0 of Set 3 | kill devil hills
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | naze
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | at taj
# Processing Record 5 of Set 3 | panaba
# Processing Record 6 of Set 3 | urangan
# Processing Record 7 of Set 3 | kourou
# Processing Record 8 of Set 3 | carutapera
# Processing Record 9 of Set 3 | kenai
# Processing Record 10 of Set 3 | hamilton
# Processing Record 11 of Set 3 | grossalmerode
# Processing Record 12 of Set 3 | shevchenko
# Processing Record 13 of Set 3 | mount pearl
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | thompson
# Processing Record 16 of Set 3 | angul
# Processing Record 17 of Set 3 | saipan
# Processing Record 18 of Set 3 | kulia village
# City not found. Skipping...
# Processing Record 19 of Set 3 | sao tome
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | la passe
# Processing Record 22 of Set 3 | merizo village
# Processing Record 23 of Set 3 | waddan
# Processing Record 24 of Set 3 | yemva
# Processing Record 25 of Set 3 | acapulco de juarez
# Processing Record 26 of Set 3 | kursavka
# Processing Record 27 of Set 3 | dingli
# Processing Record 28 of Set 3 | mantsala
# Processing Record 29 of Set 3 | tabou
# Processing Record 30 of Set 3 | ghat
# Processing Record 31 of Set 3 | hargeysa
# Processing Record 32 of Set 3 | valdovino
# Processing Record 33 of Set 3 | al burayqah
# Processing Record 34 of Set 3 | luderitz
# Processing Record 35 of Set 3 | kannangad
# Processing Record 36 of Set 3 | bredasdorp
# Processing Record 37 of Set 3 | slave lake
# Processing Record 38 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 39 of Set 3 | tura
# Processing Record 40 of Set 3 | college
# Processing Record 41 of Set 3 | forster
# Processing Record 42 of Set 3 | bilibino
# Processing Record 43 of Set 3 | ingeniero jacobacci
# Processing Record 44 of Set 3 | orkney
# Processing Record 45 of Set 3 | kyzyl
# Processing Record 46 of Set 3 | lihue
# Processing Record 47 of Set 3 | languyan
# Processing Record 48 of Set 3 | la'ie
# Processing Record 49 of Set 3 | buala
# Processing Record 0 of Set 4 | whitecourt
# City not found. Skipping...
# Processing Record 1 of Set 4 | patterson
# Processing Record 2 of Set 4 | churapcha
# Processing Record 3 of Set 4 | touba
# Processing Record 4 of Set 4 | banda aceh
# Processing Record 5 of Set 4 | buryn'
# Processing Record 6 of Set 4 | alice springs
# Processing Record 7 of Set 4 | capinota
# Processing Record 8 of Set 4 | meizhou
# Processing Record 9 of Set 4 | west island
# Processing Record 10 of Set 4 | egilsstadir
# Processing Record 11 of Set 4 | warrnambool
# Processing Record 12 of Set 4 | puerto cabezas
# Processing Record 13 of Set 4 | pacific grove
# Processing Record 14 of Set 4 | nangong
# Processing Record 15 of Set 4 | hemsby
# Processing Record 16 of Set 4 | byerazino
# Processing Record 17 of Set 4 | rabo de peixe
# Processing Record 18 of Set 4 | fale old settlement
# Processing Record 19 of Set 4 | pangkalanbuun
# Processing Record 20 of Set 4 | badger
# Processing Record 21 of Set 4 | chiili
# City not found. Skipping...
# Processing Record 22 of Set 4 | sechura
# Processing Record 23 of Set 4 | general conesa
# Processing Record 24 of Set 4 | tansen
# Processing Record 25 of Set 4 | anadyr
# Processing Record 26 of Set 4 | burang
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | suva
# Processing Record 30 of Set 4 | vernon
# Processing Record 31 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 32 of Set 4 | morshansk
# Processing Record 33 of Set 4 | aripuana
# Processing Record 34 of Set 4 | wajir
# Processing Record 35 of Set 4 | isafjordur
# Processing Record 36 of Set 4 | valparaiso
# Processing Record 37 of Set 4 | labasa
# Processing Record 38 of Set 4 | bungu
# Processing Record 39 of Set 4 | dharan
# Processing Record 40 of Set 4 | shawano
# Processing Record 41 of Set 4 | ola
# Processing Record 42 of Set 4 | caleta de carquin
# Processing Record 43 of Set 4 | talara
# Processing Record 44 of Set 4 | colonia
# Processing Record 45 of Set 4 | barra de santo antonio
# Processing Record 46 of Set 4 | qaqortoq
# Processing Record 47 of Set 4 | tocoa
# Processing Record 48 of Set 4 | chilaw
# Processing Record 49 of Set 4 | dunedin
# Processing Record 0 of Set 5 | zaragoza
# Processing Record 1 of Set 5 | kijang
# Processing Record 2 of Set 5 | vieste
# Processing Record 3 of Set 5 | shohimardon
# Processing Record 4 of Set 5 | gaoual
# Processing Record 5 of Set 5 | al manzalah
# Processing Record 6 of Set 5 | tinajo
# Processing Record 7 of Set 5 | new norfolk
# Processing Record 8 of Set 5 | onokhoy
# Processing Record 9 of Set 5 | nadi
# Processing Record 10 of Set 5 | gadzhiyevo
# Processing Record 11 of Set 5 | oroqen zizhiqi
# Processing Record 12 of Set 5 | afaahiti
# Processing Record 13 of Set 5 | nacala
# Processing Record 14 of Set 5 | soledade
# Processing Record 15 of Set 5 | san antonio de pale
# Processing Record 16 of Set 5 | tralee
# Processing Record 17 of Set 5 | villa dolores
# Processing Record 18 of Set 5 | isangel
# Processing Record 19 of Set 5 | vallenar
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | sarmiento
# Processing Record 22 of Set 5 | yanchep
# Processing Record 23 of Set 5 | mirpur sakro
# Processing Record 24 of Set 5 | jinghong
# Processing Record 25 of Set 5 | sinop
# Processing Record 26 of Set 5 | bucecea
# Processing Record 27 of Set 5 | nova sintra
# Processing Record 28 of Set 5 | altay
# Processing Record 29 of Set 5 | siwa oasis
# Processing Record 30 of Set 5 | yantongshan
# Processing Record 31 of Set 5 | polyarnyy
# Processing Record 32 of Set 5 | choibalsan
# Processing Record 33 of Set 5 | bayji
# Processing Record 34 of Set 5 | pacasmayo
# Processing Record 35 of Set 5 | la sarre
# Processing Record 36 of Set 5 | hasaki
# Processing Record 37 of Set 5 | wenchang
# Processing Record 38 of Set 5 | nema
# Processing Record 39 of Set 5 | mhamid
# Processing Record 40 of Set 5 | topolobampo
# Processing Record 41 of Set 5 | mount isa
# Processing Record 42 of Set 5 | murowana goslina
# Processing Record 43 of Set 5 | tromso
# Processing Record 44 of Set 5 | puerto ayora
# Processing Record 45 of Set 5 | lompoc
# Processing Record 46 of Set 5 | shentala
# Processing Record 47 of Set 5 | sao joao da barra
# Processing Record 48 of Set 5 | dudinka
# Processing Record 49 of Set 5 | kurayoshi
# Processing Record 0 of Set 6 | lyepyel'
# Processing Record 1 of Set 6 | pisco
# Processing Record 2 of Set 6 | saldanha
# Processing Record 3 of Set 6 | itaituba
# Processing Record 4 of Set 6 | simplicio mendes
# Processing Record 5 of Set 6 | talnakh
# Processing Record 6 of Set 6 | yelizovo
# Processing Record 7 of Set 6 | manta
# Processing Record 8 of Set 6 | qingnian
# Processing Record 9 of Set 6 | haiku-pauwela
# Processing Record 10 of Set 6 | howard springs
# Processing Record 11 of Set 6 | fayroz koh
# Processing Record 12 of Set 6 | portland
# Processing Record 13 of Set 6 | puerto baquerizo moreno
# Processing Record 14 of Set 6 | tambacounda
# Processing Record 15 of Set 6 | caarapo
# Processing Record 16 of Set 6 | saint-pierre
# Processing Record 17 of Set 6 | vadso
# Processing Record 18 of Set 6 | yaransk
# Processing Record 19 of Set 6 | evanston
# Processing Record 20 of Set 6 | nemuro
# Processing Record 21 of Set 6 | akrehamn
# Processing Record 22 of Set 6 | cabo san lucas
# Processing Record 23 of Set 6 | east london
# Processing Record 24 of Set 6 | ichnya
# Processing Record 25 of Set 6 | iskateley
# Processing Record 26 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 27 of Set 6 | beloyarskiy
# Processing Record 28 of Set 6 | kamen'-na-obi
# Processing Record 29 of Set 6 | itoigawa
# Processing Record 30 of Set 6 | constitucion
# Processing Record 31 of Set 6 | port alfred
# Processing Record 32 of Set 6 | vilyuysk
# Processing Record 33 of Set 6 | weno
# Processing Record 34 of Set 6 | las vegas
# Processing Record 35 of Set 6 | hilo
# Processing Record 36 of Set 6 | basotu
# Processing Record 37 of Set 6 | cantagalo
# Processing Record 38 of Set 6 | iquique
# Processing Record 39 of Set 6 | misratah
# Processing Record 40 of Set 6 | soanierana ivongo
# Processing Record 41 of Set 6 | anloga
# Processing Record 42 of Set 6 | sefwi wiawso
# City not found. Skipping...
# Processing Record 43 of Set 6 | tucuma
# Processing Record 44 of Set 6 | kingston
# Processing Record 45 of Set 6 | grand-bassam
# Processing Record 46 of Set 6 | fort st. john
# Processing Record 47 of Set 6 | ozu
# Processing Record 48 of Set 6 | tsiombe
# Processing Record 49 of Set 6 | port moresby
# Processing Record 0 of Set 7 | mirny
# Processing Record 1 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 2 of Set 7 | sitka
# Processing Record 3 of Set 7 | vorkuta
# Processing Record 4 of Set 7 | antsiranana
# Processing Record 5 of Set 7 | tipasa
# Processing Record 6 of Set 7 | punta del este
# Processing Record 7 of Set 7 | queenstown
# Processing Record 8 of Set 7 | mil'kovo
# Processing Record 9 of Set 7 | coahuayana de hidalgo
# Processing Record 10 of Set 7 | soufriere
# Processing Record 11 of Set 7 | sinan
# Processing Record 12 of Set 7 | val-d'or
# Processing Record 13 of Set 7 | nehe
# Processing Record 14 of Set 7 | udachny
# Processing Record 15 of Set 7 | urumqi
# Processing Record 16 of Set 7 | callao
# Processing Record 17 of Set 7 | zinjibar
# Processing Record 18 of Set 7 | kudahuvadhoo
# Processing Record 19 of Set 7 | phang nga
# Processing Record 20 of Set 7 | gobabis
# Processing Record 21 of Set 7 | happy valley-goose bay
# Processing Record 22 of Set 7 | changji
# Processing Record 23 of Set 7 | flying fish cove
# Processing Record 24 of Set 7 | tindouf
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | kunshan
# Processing Record 27 of Set 7 | fort mcmurray
# Processing Record 28 of Set 7 | constantia
# Processing Record 29 of Set 7 | am timan
# Processing Record 30 of Set 7 | ostersund
# Processing Record 31 of Set 7 | kerikeri
# Processing Record 32 of Set 7 | tadine
# Processing Record 33 of Set 7 | marquette
# Processing Record 34 of Set 7 | andergrove
# Processing Record 35 of Set 7 | brisas de zicatela
# Processing Record 36 of Set 7 | prainha
# Processing Record 37 of Set 7 | zhanga buqtyrma
# Processing Record 38 of Set 7 | loch garman
# Processing Record 39 of Set 7 | usogorsk
# Processing Record 40 of Set 7 | vorgashor
# Processing Record 41 of Set 7 | san andres
# Processing Record 42 of Set 7 | urazovo
# Processing Record 43 of Set 7 | greater sudbury
# Processing Record 44 of Set 7 | mili
# Processing Record 45 of Set 7 | ambato
# Processing Record 46 of Set 7 | igarka
# Processing Record 47 of Set 7 | segezha
# Processing Record 48 of Set 7 | ngara
# Processing Record 49 of Set 7 | tintafor
# Processing Record 0 of Set 8 | gallivare
# City not found. Skipping...
# Processing Record 1 of Set 8 | nikolayevsk-on-amure
# Processing Record 2 of Set 8 | fairfield
# Processing Record 3 of Set 8 | yemetsk
# Processing Record 4 of Set 8 | timimoun
# Processing Record 5 of Set 8 | pimentel
# Processing Record 6 of Set 8 | utrik
# Processing Record 7 of Set 8 | tosontsengel
# Processing Record 8 of Set 8 | greymouth
# Processing Record 9 of Set 8 | lata
# Processing Record 10 of Set 8 | cidreira
# Processing Record 11 of Set 8 | san carlos
# Processing Record 12 of Set 8 | sonsorol village
# City not found. Skipping...
# Processing Record 13 of Set 8 | luena
# Processing Record 14 of Set 8 | antofagasta
# Processing Record 15 of Set 8 | lovech
# Processing Record 16 of Set 8 | youkounkoun
# Processing Record 17 of Set 8 | manacapuru
# Processing Record 18 of Set 8 | klaksvik
# Processing Record 19 of Set 8 | shangri-la
# City not found. Skipping...
# Processing Record 20 of Set 8 | poronaysk
# Processing Record 21 of Set 8 | polessk
# Processing Record 22 of Set 8 | mims
# Processing Record 23 of Set 8 | thurso
# Processing Record 24 of Set 8 | karakol
# Processing Record 25 of Set 8 | tobelo
# Processing Record 26 of Set 8 | chimoio
# Processing Record 27 of Set 8 | barrinha
# Processing Record 28 of Set 8 | semenivka
# Processing Record 29 of Set 8 | prince rupert
# Processing Record 30 of Set 8 | namibe
# Processing Record 31 of Set 8 | tiaret
# Processing Record 32 of Set 8 | santa lucia
# Processing Record 33 of Set 8 | makueni boma
# Processing Record 34 of Set 8 | cururupu
# Processing Record 35 of Set 8 | kosciuszko national park
# City not found. Skipping...
# Processing Record 36 of Set 8 | port saint john's
# Processing Record 37 of Set 8 | akureyri
# Processing Record 38 of Set 8 | tazovsky
# Processing Record 39 of Set 8 | kununurra
# Processing Record 40 of Set 8 | morristown
# Processing Record 41 of Set 8 | antalaha
# Processing Record 42 of Set 8 | tabas
# Processing Record 43 of Set 8 | george
# Processing Record 44 of Set 8 | kurchum
# Processing Record 45 of Set 8 | chonchi
# Processing Record 46 of Set 8 | argo
# Processing Record 47 of Set 8 | umreth
# Processing Record 48 of Set 8 | palmer
# Processing Record 49 of Set 8 | la foa
# Processing Record 0 of Set 9 | dwarka
# Processing Record 1 of Set 9 | ugoofaaru
# Processing Record 2 of Set 9 | tagiura
# Processing Record 3 of Set 9 | prado
# Processing Record 4 of Set 9 | uren'
# Processing Record 5 of Set 9 | mangrol
# Processing Record 6 of Set 9 | puerto el triunfo
# Processing Record 7 of Set 9 | holualoa
# Processing Record 8 of Set 9 | oualidia
# City not found. Skipping...
# Processing Record 9 of Set 9 | tucurui
# Processing Record 10 of Set 9 | ebon
# Processing Record 11 of Set 9 | port augusta
# Processing Record 12 of Set 9 | saguenay
# Processing Record 13 of Set 9 | oliver
# Processing Record 14 of Set 9 | mount gambier
# Processing Record 15 of Set 9 | horishni plavni
# Processing Record 16 of Set 9 | hithadhoo
# Processing Record 17 of Set 9 | duluth
# Processing Record 18 of Set 9 | tateyama
# Processing Record 19 of Set 9 | praia da vitoria
# Processing Record 20 of Set 9 | tubarjal
# Processing Record 21 of Set 9 | tarawa
# Processing Record 22 of Set 9 | rio de janeiro
# Processing Record 23 of Set 9 | karasburg
# Processing Record 24 of Set 9 | shimoda
# Processing Record 25 of Set 9 | gusinoozyorsk
# Processing Record 26 of Set 9 | quelimane
# Processing Record 27 of Set 9 | arkhangel'sk
# Processing Record 28 of Set 9 | kapuskasing
# Processing Record 29 of Set 9 | mejit
# Processing Record 30 of Set 9 | midelt
# Processing Record 31 of Set 9 | carmelo
# Processing Record 32 of Set 9 | lebork
# Processing Record 33 of Set 9 | broome
# Processing Record 34 of Set 9 | moultrie
# Processing Record 35 of Set 9 | ghadamis
# Processing Record 36 of Set 9 | bataipora
# Processing Record 37 of Set 9 | salinopolis
# Processing Record 38 of Set 9 | obo
# Processing Record 39 of Set 9 | waterboro
# Processing Record 40 of Set 9 | nantucket
# Processing Record 41 of Set 9 | naolinco de victoria
# Processing Record 42 of Set 9 | vanino
# Processing Record 43 of Set 9 | pyt-yakh
# Processing Record 44 of Set 9 | santyoku
# Processing Record 45 of Set 9 | deschutes river woods
# Processing Record 46 of Set 9 | hanceville
# Processing Record 47 of Set 9 | chibougamau
# Processing Record 48 of Set 9 | cosala
# Processing Record 49 of Set 9 | oxapampa
# Processing Record 0 of Set 10 | kapa'a
# Processing Record 1 of Set 10 | lander
# Processing Record 2 of Set 10 | ilha de mocambique
# Processing Record 3 of Set 10 | canyon
# Processing Record 4 of Set 10 | berdigestyakh
# Processing Record 5 of Set 10 | manokwari
# Processing Record 6 of Set 10 | toliara
# Processing Record 7 of Set 10 | puerto san jose
# Processing Record 8 of Set 10 | westport
# Processing Record 9 of Set 10 | kargil
# Processing Record 10 of Set 10 | pierre
# Processing Record 11 of Set 10 | kruisfontein
# Processing Record 12 of Set 10 | sao vicente
# Processing Record 13 of Set 10 | breves
# Processing Record 14 of Set 10 | newman
# Processing Record 15 of Set 10 | macapa
# Processing Record 16 of Set 10 | craig
# Processing Record 17 of Set 10 | pangoa
# Processing Record 18 of Set 10 | parabel'
# Processing Record 19 of Set 10 | lorengau
# Processing Record 20 of Set 10 | waspan
# Processing Record 21 of Set 10 | hami
# Processing Record 22 of Set 10 | georgievka
# Processing Record 23 of Set 10 | hede
# Processing Record 24 of Set 10 | mariental
# Processing Record 25 of Set 10 | touros
# Processing Record 26 of Set 10 | terenozek
# Processing Record 27 of Set 10 | sabang
# Processing Record 28 of Set 10 | lyantor
# Processing Record 29 of Set 10 | ketchikan
# Processing Record 30 of Set 10 | kulhudhuffushi
# Processing Record 31 of Set 10 | vernal
# Processing Record 32 of Set 10 | dien bien phu
# Processing Record 33 of Set 10 | west bay
# Processing Record 34 of Set 10 | gypsum
# Processing Record 35 of Set 10 | francisco i. madero
# Processing Record 36 of Set 10 | sumbawa besar
# Processing Record 37 of Set 10 | nar'yan-mar
# Processing Record 38 of Set 10 | nova xavantina
# Processing Record 39 of Set 10 | ajaccio
# Processing Record 40 of Set 10 | oodweyne
# Processing Record 41 of Set 10 | ormara
# Processing Record 42 of Set 10 | tanjung pandan
# Processing Record 43 of Set 10 | la ronge
# Processing Record 44 of Set 10 | bou hanifia el hamamat
# Processing Record 45 of Set 10 | porto novo
# Processing Record 46 of Set 10 | lianjiang
# Processing Record 47 of Set 10 | sogndal
# Processing Record 48 of Set 10 | christchurch
# Processing Record 49 of Set 10 | espargos
# City not found. Skipping...
# Processing Record 0 of Set 11 | rikaze
# Processing Record 1 of Set 11 | northam
# Processing Record 2 of Set 11 | pangody
# Processing Record 3 of Set 11 | dabhol
# Processing Record 4 of Set 11 | vilhena
# Processing Record 5 of Set 11 | ceeldheer
# Processing Record 6 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 7 of Set 11 | el calafate
# Processing Record 8 of Set 11 | golfito
# Processing Record 9 of Set 11 | kataragama
# City not found. Skipping...
# Processing Record 10 of Set 11 | lazaro cardenas
# Processing Record 11 of Set 11 | luganville
# Processing Record 12 of Set 11 | tsiroanomandidy
# Processing Record 13 of Set 11 | guardo
# Processing Record 14 of Set 11 | ulladulla
# Processing Record 15 of Set 11 | griffith
# Processing Record 16 of Set 11 | petrov val
# Processing Record 17 of Set 11 | angra do heroismo
# Processing Record 18 of Set 11 | pagar alam
# Processing Record 19 of Set 11 | la tuque
# Processing Record 20 of Set 11 | ayaguz
# City not found. Skipping...
# Processing Record 21 of Set 11 | alexandria
# Processing Record 22 of Set 11 | el granada
# Processing Record 23 of Set 11 | margate
# Processing Record 24 of Set 11 | selfoss
# Processing Record 25 of Set 11 | maria la baja
# Processing Record 26 of Set 11 | laojunmiao
# Processing Record 27 of Set 11 | okhotsk
# Processing Record 28 of Set 11 | gereida
# Processing Record 29 of Set 11 | cabedelo
# Processing Record 30 of Set 11 | xam nua
# Processing Record 31 of Set 11 | zhezqazghan
# Processing Record 32 of Set 11 | inarajan village
# Processing Record 33 of Set 11 | tapejara
# Processing Record 34 of Set 11 | ta`u
# Processing Record 35 of Set 11 | coquimbo
# Processing Record 36 of Set 11 | namsos
# Processing Record 37 of Set 11 | itoman
# Processing Record 38 of Set 11 | orsa
# Processing Record 39 of Set 11 | alenquer
# Processing Record 40 of Set 11 | laguna
# Processing Record 41 of Set 11 | cochrane
# Processing Record 42 of Set 11 | pariaman
# Processing Record 43 of Set 11 | champerico
# Processing Record 44 of Set 11 | acarau
# Processing Record 45 of Set 11 | fauske
# Processing Record 46 of Set 11 | qulsary
# Processing Record 47 of Set 11 | xuddur
# Processing Record 48 of Set 11 | viedma
# Processing Record 49 of Set 11 | papao
# Processing Record 0 of Set 12 | pathein
# Processing Record 1 of Set 12 | alta
# Processing Record 2 of Set 12 | fisterra
# Processing Record 3 of Set 12 | banff
# Processing Record 4 of Set 12 | phan rang-thap cham
# Processing Record 5 of Set 12 | qamdo
# Processing Record 6 of Set 12 | luanda
# Processing Record 7 of Set 12 | port douglas
# Processing Record 8 of Set 12 | loiza
# Processing Record 9 of Set 12 | kertih
# Processing Record 10 of Set 12 | cavite city
# Processing Record 11 of Set 12 | scone
# Processing Record 12 of Set 12 | linxia chengguanzhen
# Processing Record 13 of Set 12 | vila do maio
# Processing Record 14 of Set 12 | mahina
# Processing Record 15 of Set 12 | qarauyl
# Processing Record 16 of Set 12 | kipushi
# Processing Record 17 of Set 12 | keetmanshoop
# Processing Record 18 of Set 12 | kalix
# Processing Record 19 of Set 12 | porto seguro
# Processing Record 20 of Set 12 | paredon
# Processing Record 21 of Set 12 | gueltat zemmour
# City not found. Skipping...
# Processing Record 22 of Set 12 | el hamma
# Processing Record 23 of Set 12 | fortuna
# Processing Record 24 of Set 12 | vila franca do campo
# Processing Record 25 of Set 12 | al mayadin
# Processing Record 26 of Set 12 | kodarma
# Processing Record 27 of Set 12 | mata-utu
# Processing Record 28 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 29 of Set 12 | arawa
# Processing Record 30 of Set 12 | xilin hot
# Processing Record 31 of Set 12 | shingu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        tsarevo  42.1667   27.8500     18.87        81           1
# 1   muzaffarabad  34.3700   73.4711     25.77        68           4
# 2       waitangi -43.9535 -176.5597     11.01        88          19
# 3     nelson bay -32.7167  152.1500     15.62        69          69
# 4  cockburn town  21.4612  -71.1419     27.67        88          99
#
#    Wind Speed Country        Date
# 0        4.42      BG  1719622885
# 1        1.57      PK  1719622886
# 2        1.34      NZ  1719622889
# 3        0.89      AU  1719622890
# 4        7.47      TC  1719622664

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              tsarevo  42.1667   27.8500     18.87        81           1
# 1         muzaffarabad  34.3700   73.4711     25.77        68           4
# 2             waitangi -43.9535 -176.5597     11.01        88          19
# 3           nelson bay -32.7167  152.1500     15.62        69          69
# 4        cockburn town  21.4612  -71.1419     27.67        88          99
#
#          Wind Speed Country        Date
# City_ID
# 0              4.42      BG  1719622885
# 1              1.57      PK  1719622886
# 2              1.34      NZ  1719622889
# 3              0.89      AU  1719622890
# 4              7.47      TC  1719622664

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date=city_data_df['Date'].min()
plt.title(f"City Latitude vs. Temperature ({date})")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lr_funcV2(x,y,name,vbl,hemi):
    (slope,intercept,rvalue,pvalue,stderror)=linregress(x,y)
    reg_values= x*slope + intercept
    plt.plot(x,reg_values,color='r')
    plt.title(f'Latitude vs. {vbl} - {hemi}')
    plt.xlabel('Latitude')
    plt.ylabel(vbl)
    line_eq = f'y = {(round(slope,2))}x + {(round(intercept,2))}'
    print(f'Linear equation: {line_eq}')
    plt.savefig(f"output_data/LinearRegresion_{name}.png")
    print(f'The r-value is: {rvalue}')

x = ['Lat']
y = ['Max Temp']
name = 'NH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[22], line 19
#      17 vbl = 'Maximum Temperature C°'
#      18 hemi = 'Northern Hemisphere'
# ---> 19 lr_funcV2(x,y,name,vbl,hemi)
#      20 plt.show()
#
# Cell In[22], line 3, in lr_funcV2(x, y, name, vbl, hemi)
#       2 def lr_funcV2(x,y,name,vbl,hemi):
# ----> 3     (slope,intercept,rvalue,pvalue,stderror)=linregress(x,y)
#       4     reg_values= x*slope + intercept
#       5     plt.plot(x,reg_values,color='r')
#
# File /opt/anaconda3/envs/PythonData_2024_04/lib/python3.12/site-packages/scipy/stats/_stats_mstats_common.py:156, in linregress(x, y, alternative)
#     153 if x.size == 0 or y.size == 0:
#     154     raise ValueError("Inputs must not be empty.")
# --> 156 if np.amax(x) == np.amin(x) and len(x) > 1:
#     157     raise ValueError("Cannot calculate a linear regression "
#     158                      "if all x values are identical")
#     160 n = len(x)
#
# File /opt/anaconda3/envs/PythonData_2024_04/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2827, in amax(a, axis, out, keepdims, initial, where)
#    2814 @array_function_dispatch(_max_dispatcher)
#    2815 def amax(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2816          where=np._NoValue):
#    2817     """
#    2818     Return the maximum of an array or maximum along an axis.
#    2819
#    (...)
#    2825     ndarray.max : equivalent method
#    2826     """
# -> 2827     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2828                           keepdims=keepdims, initial=initial, where=where)
#
# File /opt/anaconda3/envs/PythonData_2024_04/lib/python3.12/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# UFuncTypeError: ufunc 'maximum' did not contain a loop with signature matching types (dtype('<U3'), dtype('<U3')) -> None

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0,:]

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<= 0,:]

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# %%
# Linear regression on Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')
plt.grid()

x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
name = 'NH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')

plt.grid()

x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']
name = 'SH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# there is a positive correalation between latitude and humidity

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

plt.grid()

x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']
name = 'NH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

plt.grid()

x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']
name = 'SH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# there are warmer tempatures towards the equators and each equator has the opposite positive and negative correlatioin

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

plt.grid()

x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
name = 'NH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

plt.grid()

x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
name = 'SH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
each hemishphere has a slight positive correlation
